# %%
#This is the notebook for ASTR 19 Group Project.

# %%
#import basics
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import optimize
from scipy.optimize import curve_fit

# %%
#Upload text data
#named the text fname, to make calling it easier.
fname = 'ASTR19_S22_group_project_data.txt'
#data = np.genfromtxt(fname, dtype=None) #another variation to call, text, ignore.
data = np.loadtxt(fname,dtype=np.ndarray) #loaded the data as an array, named it data.
print(type(data))
#print(data)
# Out:
# <class 'numpy.ndarray'>

# %%
x = []
y = []

for entry in data:
    time = float(entry[1].replace(":", "")) / 2400.0
    date = float(entry[0]) + time
    
    x.append(date)
    y.append(float(entry[2]))
matrix = [[x[i], y[i]] for i in range(len(x))]

# %%
#convert x and y into numpy arrays 
x = np.array(x)
y = np.array(y)

# %%
#curve fitting
npoints = 82
#IGNORE GUESS FUNC, USING F_LINE
def guess(x, a, b, c, d):
    return a * np.sin(b * x + c) + d # TODO: put sin(4x)cos(x) here






a = 4.0
sig = 0.25

def f_line(x,a):
    return np.sin(a*x)*np.cos(x)

y_err = np.full(npoints,sig)

#perform the fit
params, param_cov = optimize.curve_fit(f_line, x,y,sigma=y_err,p0=20)

a_fit = params[0]

print(a_fit)
y_fit = np.sin(a_fit*x)*np.cos(x)
#residual is the distance from point to optimized curve 
#p0=the min, don't let the computer guess that
# Out:
# 20.009314072733016

# %%
#TESTING SECTION
b = 10.0
c = 2.0
d = 3.0
sig = 0.25
def testguess(x,b,c,d):
    return np.sin(b*x)+(c*np.sin(x))+(d*np.sin(d*x))

testy_err = np.full(npoints,sig)
print(params[0])


#perform the fit
params, param_cov = optimize.curve_fit(f_line,x,y,sigma=y_err)
b_fit=params[0]
c_fit =params[0]
d_fit = params[0]

#print(b_fit)
testy_fit = np.sin(b_fit*x)+(c_fit*np.sin(x))+(d_fit*np.sin(d_fit*x))
# Out:
# 1.0523054771855256

# %%
#errorbar version
npoints = len(x)


f = plt.figure(figsize=(7, 7))
y_err = np.full(npoints, sig)

plt.errorbar(x, y, yerr=y_err, fmt="o")
plt.plot(x,y_fit)
plt.plot(x,testy_fit)
plt.xlabel("Time")
plt.ylabel("Tide")
print(y)
print(testy_fit)
# Out:
# [ 6.57 -0.39  5.38 -1.74  5.26 -1.36  4.13 -1.15  3.48 -1.61  2.62  0.05
#   1.83  1.01  3.57  0.73  4.54  2.17  3.76  2.88  3.9   1.92  4.73  1.74
#   5.66  0.79  5.33 -0.04  5.23 -1.12  6.67 -0.61  4.74 -0.93  4.69 -1.29
#   4.2   0.22  3.68  0.26  2.47  0.36  2.59  0.99  4.1   1.87  3.17  1.6
#   3.71  3.1   4.04  2.49  4.07  2.18  5.93  0.7   6.89  0.21  6.72  0.22
#   6.77 -1.68  5.77 -1.32  4.35 -0.73  4.23 -0.38  2.24 -0.61  3.45 -0.46
#   4.13  1.21  3.34  2.58  3.32  3.26  5.21  2.39  4.83  2.41]
# [ 3.04804182  3.07732349  2.00575263  1.12573017 -1.11747237 -1.99416327
#  -3.06079784 -3.02046621 -1.79680246 -0.94975599  1.33712543  2.10242082
#   3.04808106  2.94560896  2.57346948  0.72395205 -0.19109421 -2.18829156
#  -2.70210153 -2.96784306 -2.4368014  -1.78384848  0.33685886  1.23743545
#   2.70198527  2.92426248  2.29511565  1.57123537 -0.41521713 -1.32541751
#  -2.67439167 -2.84491071 -2.13953196 -1.45671104  0.53202291  1.38886929
#   2.624888    2.74519276  2.00269183  1.29863334 -0.64924556 -1.39893252
#  -2.55826538 -2.6262821  -2.45621517 -1.17063423 -0.42026416  1.44307102
#   1.99752237  2.36162847  2.27634799  1.84065875  0.18773926 -0.58713707
#  -2.01742887 -2.30570034 -2.03809878 -1.56444164  0.02000783  0.76458042
#   1.98729976  2.1997069   1.80380294  1.3315734  -0.24177866 -0.86367578
#  -1.93611262 -2.05928221 -1.53422412 -1.10399165 -0.55812815  0.93414972
#   1.38974521  1.89865035  1.80275311  1.54111544  0.34402892 -0.27091942
#  -1.38786219 -1.66186461 -1.56135981 -1.21421798]

# %%
plt.plot(x, y)
plt.plot(x,y_fit)
plt.plot(x,testy_fit)
plt.xlabel("Time")
plt.ylabel("Tide")
# Out:
# Text(0, 0.5, 'Tide')
